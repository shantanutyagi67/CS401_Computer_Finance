# %% [markdown]
# ## Question 1

# %%
import random
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import math

# %%
def brownian(s,t,n):
    np.random.seed(s)
    y = np.random.normal(loc=0, scale=1, size=int(t*n))/math.sqrt(n)
    x = np.linspace(0,t,num=int(t*n))
    w = np.zeros(int(t*n))
    for i in range(int(t*n)-1):
        w[i+1] = y[i]
    for i in range(int(t*n)-1):
        w[i+1] = w[i+1]+w[i]
    return x,w
def plotB(x,w):
    plt.figure(figsize=(15, 6))
    plt.plot(x,w)
    plt.title('Regular Brownian Motion from Normal Distribution', fontsize=30)
    plt.ylabel('W', fontsize=15)
    plt.xlabel('Time', fontsize=15)
    plt.grid()
    plt.show()
x,w = brownian(5,10,64)
plotB(x,w)

# %% [markdown]
# ## Question 2

# %%
def geoBrownStock(s0,mu,sigma,t,n,seed):
    s = np.zeros(int(t*n))
    x,w = brownian(seed,t,n)
    plotB(x,w)
    for i in range(int(t*n)):
        s[i] = s0*pow( np.e, ((mu-sigma*sigma/2)*(i/(int(n*t))) + (sigma*w[i]) ) )
    plt.figure(figsize=(15, 6))
    plt.plot(x,s)
    plt.title('Stock Price using Geometric Brownian Motion', fontsize=30)
    plt.ylabel('S', fontsize=15)
    plt.xlabel('Time', fontsize=15)
    plt.grid()
    plt.show()
geoBrownStock(55.25,0.15,0.4,2,64,5)

# %% [markdown]
# ## Here, N = 64, T = 2

# %% [markdown]
# ## Question 3

# %%
df = pd.read_csv('REL.csv')
df = df.iloc[::-1]
df1 = df['Close Price']
plt.figure(figsize=(15, 6))
plt.plot(np.linspace(0,2,df1.size),df1)
plt.title('Original Stock Price using Data', fontsize=30)
plt.ylabel('W', fontsize=15)
plt.xlabel('Time', fontsize=15)
plt.grid()
plt.show()
s0 = df1[0]
df1 = np.array(df1)
df2 = np.zeros(df1.size-1)
summ = 0
for i in range(df1.size-1):
    df2[i] = (df1[i+1]-df1[i])/df1[i]
mu = df2.mean()*365
df3 = np.zeros(df1.size-1)
for i in range(1,df3.size+1):
    df3[i-1] = np.log(df1[i]/df1[i-1])
mean = df3.mean()
s = 0;
for i in range(df3.size):
    s = s + (df3[i] - mean)*(df3[i] - mean)
s = s / (df3.size - 1)
s = math.sqrt(s)
sigma = s / math.sqrt(1/365.00)
geoBrownStock(s0,mu,sigma,df1.size/365.00,365.00,22)

# %% [markdown]
# ## Here, T = 2511/365, N = 365

# %%
sigma
# Out:
# 0.4357231756110739

# %%
mu
# Out:
# 0.187030447525858

# %%
s0
# Out:
# 2082.75
